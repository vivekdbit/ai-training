# %%
# Text loadder
from langchain_community.document_loaders import TextLoader
loader = TextLoader('documents/sample.txt')

text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'documents/sample.txt'}, page_content="Credit Cards\nCanada's Best Credit Cards for February 2025\nCanada’s Best Credit Cards for February 2025\nFeb 3, 2025\nNerdWallet Canada’s picks for the best credit cards include top contenders across numerous card categories. Compare these options to find the ideal card for you.\nProfile photo of Shannon Terrell\nWritten by Shannon Terrell\nLead Writer\nProfile photo of Athena Cocoves\nEdited by Athena Cocoves\nAssigning Editor\nMany or all of the products featured here are from our partners who compensate us. This may influence which products we write about and where and how the product appears on a page. However, this does not influence our evaluations. Our opinions are our own.\nChoosing the best credit card is part art, part science. Whether you're chasing rewards or cutting costs, no single option works for everyone. That's why our experts compared hundreds of cards across several categories to help narrow dow
# ...

# %%
type(text_document) # List
type(text_document[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ### How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_doc = text_splitter.split_documents(text_document)
final_doc
# Out:
# [Document(metadata={'source': 'documents/sample.txt'}, page_content="Credit Cards\nCanada's Best Credit Cards for February 2025\nCanada’s Best Credit Cards for February 2025\nFeb 3, 2025\nNerdWallet Canada’s picks for the best credit cards include top contenders across numerous card categories. Compare these options to find the ideal card for you.\nProfile photo of Shannon Terrell\nWritten by Shannon Terrell\nLead Writer\nProfile photo of Athena Cocoves\nEdited by Athena Cocoves\nAssigning Editor"),
#  Document(metadata={'source': 'documents/sample.txt'}, page_content='Edited by Athena Cocoves\nAssigning Editor\nMany or all of the products featured here are from our partners who compensate us. This may influence which products we write about and where and how the product appears on a page. However, this does not influence our evaluations. Our opinions are our own.'),
# ...

# %%
final_doc[0]
# Out:
# Document(metadata={'source': 'documents/sample.txt'}, page_content="Credit Cards\nCanada's Best Credit Cards for February 2025\nCanada’s Best Credit Cards for February 2025\nFeb 3, 2025\nNerdWallet Canada’s picks for the best credit cards include top contenders across numerous card categories. Compare these options to find the ideal card for you.\nProfile photo of Shannon Terrell\nWritten by Shannon Terrell\nLead Writer\nProfile photo of Athena Cocoves\nEdited by Athena Cocoves\nAssigning Editor")

# %%
# Text loadder
from langchain_community.document_loaders import TextLoader
loader = TextLoader('documents/sample.txt')
text_document_1 = loader.load()

# %%
text_splitter_1 = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=50)
final_doc_1 = text_splitter_1.split_documents(text_document_1)
print(final_doc_1[0])
print(final_doc_1[1])
# Out:
# page_content='Credit Cards
# Canada's Best Credit Cards for February 2025
# Canada’s Best Credit Cards for February 2025
# Feb 3, 2025
# NerdWallet Canada’s picks for the best credit cards include top contenders across numerous card categories. Compare these options to find the ideal card for you.
# Profile photo of Shannon Terrell
# Written by Shannon Terrell
# Lead Writer
# Profile photo of Athena Cocoves' metadata={'source': 'documents/sample.txt'}
# page_content='Lead Writer
# Profile photo of Athena Cocoves
# Edited by Athena Cocoves
# Assigning Editor
# Many or all of the products featured here are from our partners who compensate us. This may influence which products we write about and where and how the product appears on a page. However, this does not influence our evaluations. Our opinions are our own.' metadata={'source': 'documents/sample.txt'}
